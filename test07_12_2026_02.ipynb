# %% [markdown]
# <a href="https://colab.research.google.com/github/Nermen-Salama/PhD_practice/blob/main/test07_12_2026_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/acquisition_batch_02.py

# %%
# %run /content/colab_runner.py
# Out:
# 98 records in manifest
# [1/98] 97.mat  true=Normal
#     BPFO  R=0.851 z= 19.3/thr 3.8 @ -2.37% (band 2500 Hz, BPFO, duty=0.31, LATTICE) ----
#     BPFI  R=0.864 z= 21.2/thr 3.8 @ +1.56% (band 3000 Hz, BPFI, duty=0.48, LATTICE) ----
#     Ball  R=0.894 z= 23.2/thr 3.6 @ +0.77% (band 2500 Hz, 2xBSF, duty=0.42, LATTICE) ----
#     -> Normal (conf 0.50) [8.7s]  fr=29.927 (-0.08% vs prior)  multi-pass=no
# [2/98] 98.mat  true=Normal
#     BPFO  R=0.530 z= 16.9/thr 3.9 @ +2.99% (band 3500 Hz, BPFO, duty=0.34) ----
#     BPFI  R=0.597 z= 20.3/thr 3.5 @ -0.00% (band 3500 Hz, BPFI, duty=0.50) PASS
#     Ball  R=0.660 z= 23.4/thr 3.2 @ -0.78% (band 3500 Hz, 2xBSF, duty=0.43) PASS
#     -> Ball (conf 0.99) [15.8s]  fr=29.994 (+1.56% vs prior)  multi-pass=['BPFI', 'Ball']
# [3/98] 99.mat  true=Normal
#     BPFO  R=0.891 z= 12.7/thr 3.9 @ -2.36% (band 2750 Hz, BPFO, duty=0.21, LATTICE) ----
#     BPFI  R=0.601 z= 20.1/thr 4.0 @ +1.57% (band 3500 Hz, BPFI, duty=0.50, LATTICE) ----
# ...
