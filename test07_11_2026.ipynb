# %% [markdown]
# <a href="https://colab.research.google.com/github/Nermen-Salama/PhD_practice/blob/main/test07_11_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %run /content/acquisition_batch.py

# %%
# %run /content/colab_runner.py
# Out:
# 98 records in manifest
# [1/98] 97.mat  true=Normal
#     BPFO  R=0.851 @ -2.44% (null99=0.402, band 2500 Hz, BPFO, duty=0.31, LATTICE) ----
#     BPFI  R=0.825 @ +1.48% (null99=0.398, band 2500 Hz, BPFI, duty=0.49, LATTICE) ----
#     Ball  R=0.893 @ +0.69% (null99=0.364, band 2500 Hz, 2xBSF, duty=0.42, LATTICE) ----
#     -> Normal (conf 0.50) [4.1s]  multi-pass=no
# [2/98] 98.mat  true=Normal
#     BPFO  R=0.385 @ -2.37% (null99=0.358, band 3250 Hz, BPFO, duty=0.24, LATTICE) ----
#     BPFI  R=0.603 @ +1.56% (null99=0.368, band 3500 Hz, BPFI, duty=0.50, LATTICE) ----
#     Ball  R=0.684 @ +0.77% (null99=0.370, band 3250 Hz, 2xBSF, duty=0.33, LATTICE) ----
#     -> Normal (conf 0.50) [5.6s]  multi-pass=no
# [3/98] 99.mat  true=Normal
#     BPFO  R=0.385 @ -1.14% (null99=0.386, band 3250 Hz, BPFO, duty=0.24) ----
#     BPFI  R=0.599 @ +2.84% (null99=0.383, band 3500 Hz, BPFI, duty=0.50) ----
#     Ball  R=0.682 @ +2.04% (null99=0.414, band 3250 Hz, 2xBSF, duty=0.33) ----
# ...
