# %% [markdown]
# <a href="https://colab.research.google.com/github/Nermen-Salama/PhD_practice/blob/main/test07_13_2026_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/acquisition_batch_03.py

# %%
# %run /content/colab_runner_02.py
# Out:
# 98 records in manifest | CPUs available: 2 | seed=2
# [1/98] 97.mat  true=Normal
#     BPFO  R=0.842 z= 22.0/thr 3.7 @ -2.37% (band 2500 Hz, BPFO, duty=0.31, LATTICE) ----
#     BPFI  R=0.804 z= 17.8/thr 4.2 @ +1.56% (band 2500 Hz, BPFI, duty=0.49, LATTICE) ----
#     Ball  R=0.881 z= 20.6/thr 3.8 @ +0.77% (band 2500 Hz, 2xBSF, duty=0.42, LATTICE) ----
#     -> Normal (conf 0.50) [29.0s]  fr=29.927 (-0.08% vs prior)  multi-pass=no
# [2/98] 98.mat  true=Normal
#     BPFO  R=0.890 z= 18.8/thr 3.7 @ -2.37% (band 2750 Hz, BPFO, duty=0.21, LATTICE) ----
#     BPFI  R=0.598 z= 20.0/thr 4.1 @ +1.57% (band 3500 Hz, BPFI, duty=0.50, LATTICE) ----
#     Ball  R=0.686 z= 24.2/thr 3.6 @ +0.78% (band 3250 Hz, 2xBSF, duty=0.33, LATTICE) ----
#     -> Normal (conf 0.50) [62.8s]  fr=29.531 (-0.01% vs prior)  multi-pass=no
# [3/98] 99.mat  true=Normal
#     BPFO  R=0.889 z= 20.7/thr 3.6 @ -2.11% (band 2750 Hz, BPFO, duty=0.21) ----
# ...
