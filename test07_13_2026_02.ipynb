# %% [markdown]
# <a href="https://colab.research.google.com/github/Nermen-Salama/PhD_practice/blob/main/test07_13_2026_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/acquisition_batch_02.py.py

# %%
# %run /content/colab_runner.py
# Out:
# 98 records in manifest | CPUs available: 2
# [1/98] 97.mat  true=Normal
#     BPFO  R=0.851 z= 19.3/thr 3.6 @ -2.37% (band 2500 Hz, BPFO, duty=0.31, LATTICE) ----
#     BPFI  R=0.864 z= 21.2/thr 3.8 @ +1.56% (band 3000 Hz, BPFI, duty=0.48, LATTICE) ----
#     Ball  R=0.894 z= 23.2/thr 3.7 @ +0.77% (band 2500 Hz, 2xBSF, duty=0.42, LATTICE) ----
#     -> Normal (conf 0.50) [17.0s]  fr=29.928 (-0.08% vs prior)  multi-pass=no
# [2/98] 98.mat  true=Normal
#     BPFO  R=0.909 z= 10.8/thr 3.7 @ -2.36% (band 2750 Hz, BPFO, duty=0.21, LATTICE) ----
#     BPFI  R=0.613 z= 19.5/thr 4.1 @ +1.57% (band 3500 Hz, BPFI, duty=0.50, LATTICE) ----
#     Ball  R=0.686 z= 24.4/thr 4.3 @ +0.78% (band 3250 Hz, 2xBSF, duty=0.33, LATTICE) ----
#     -> Normal (conf 0.50) [31.8s]  fr=29.530 (-0.01% vs prior)  multi-pass=no
# [3/98] 99.mat  true=Normal
#     BPFO  R=0.910 z= 16.8/thr 4.3 @ -2.36% (band 2750 Hz, BPFO, duty=0.21, LATTICE) ----
# ...
